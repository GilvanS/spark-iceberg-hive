# %%
# %pip install pytest
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Conteúdo do ARQUIVO test_soma.py
import sys
import os

# Adiciona o diretório atual do script (o diretório Pytest) ao path
sys.path.insert(0, os.path.dirname(__file__)) 

from matematica import Matematica

def test_somar_corretamente(): 
    calc = Matematica()
    assert calc.somar(1, 2) == 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 6
#       3 import os
#       5 # Adiciona o diretório atual do script (o diretório Pytest) ao path
# ----> 6 sys.path.insert(0, os.path.dirname(__file__))
#       8 from matematica import Matematica
#      10 def test_somar_corretamente():
#
# NameError: name '__file__' is not defined

# %%
# !pytest test_soma.py
# ou se for um arquivo .py, basta:
# pytest test_matematica.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.5, pluggy-1.5.0
# rootdir: /opt/notebook/Unit_testing/tests/Pytest
# plugins: Faker-35.2.2, anyio-4.5.2
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# ________________________ ERROR collecting test_soma.py _________________________
# ImportError while importing test module '/opt/notebook/Unit_testing/tests/Pytest/test_soma.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.8/importlib/__init__.py:127: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# test_soma.py:2: in <module>
#     from matematica import Matematica
# E   ModuleNotFoundError: No module named 'matematica'
# =========================== short test summary info ============================
# ERROR test_soma.py
# ...
